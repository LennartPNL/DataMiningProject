# %%
import sklearn
from sklearn.linear_model import ElasticNet, Lasso, Ridge, LogisticRegression, LinearRegression
import pandas as pd 
import numpy as np 
import matplotlib as plt
from sklearn.model_selection import train_test_split
from matplotlib import pyplot
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import plot_confusion_matrix
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import r2_score

# %%
# Loading data

data = pd.read_csv("Data/student-merge.csv")
data = pd.get_dummies(data, drop_first=True)
y = data["Walc"]
X = data.drop(["Dalc","Walc"],axis=1)
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=.1)

# %%
feature_names = [atts for atts in X]
class_names = ["1","2","3","4","5"]

# %%
# Fitting several regression models to predict y

lm = LinearRegression()
lm_fit = lm.fit(X_train, y_train)

ridge = Ridge()
ridge_fit = ridge.fit(X_train,y_train)

lasso = Lasso(max_iter=1000)
lasso_fit = lasso.fit(X_train,y_train)

ENet = ElasticNet(l1_ratio=.01)
ENet_fit = ENet.fit(X_train,y_train)

preds = [[lm_fit, 'Linear Regression'], [ridge_fit, 'Ridge'], [lasso_fit, 'Lasso'], [ENet_fit, 'ElasticNet']]

# Comparing predicted y to the actual y and calculating the average

default_results = []

for p in preds:
    correct = 0
    print("===== {} =====".format(p[1]))
    print()
    for i in range(len(X_test)):
        a = p[0].predict([X_test.iloc[i]])
        msg = ""
        # The predicted values are rounded since they need to be either 1, 2, 3, 4 or 5
        if y_test.values[i] == np.around(a[0]):
            msg = "=====CORRECT====="
            correct += 1
        print("Actual= {} - Predict= {} {}".format(y_test.values[i],round(a[0],2), msg))
    print()
    print("{} had an accuracy of {}".format(p[1], correct/len(X_test)))
    default_results.append([p[1], correct/len(X_test)])
    print()
# Out:
# ===== Linear Regression =====
#
# Actual= 4 - Predict= 1.99
# Actual= 1 - Predict= 2.72
# Actual= 1 - Predict= 1.16 =====CORRECT=====
# Actual= 1 - Predict= 2.34
# Actual= 2 - Predict= 2.56
# Actual= 2 - Predict= 1.69 =====CORRECT=====
# Actual= 3 - Predict= 1.99
# Actual= 3 - Predict= 2.21
# Actual= 2 - Predict= 1.43
# Actual= 2 - Predict= 2.05 =====CORRECT=====
# Actual= 1 - Predict= 2.36
# Actual= 4 - Predict= 3.58 =====CORRECT=====
# Actual= 3 - Predict= 2.42
# Actual= 1 - Predict= 1.42 =====CORRECT=====
# Actual= 2 - Predict= 2.21 =====CORRECT=====
# Actual= 2 - Predict= 2.25 =====CORRECT=====
# Actual= 1 - Predict= 2.19
# Actual= 4 - Predict= 3.08
# Actual= 2 - Predict= 2.92
# Actual= 2 - Predict= 2.05 =====CORRECT=====
# Actual= 3 - Predict= 2.06
# Actual= 4 - Predict= 3.33
# Actual= 2 - Predict= 2.62
# Actual= 2 - Predict= 1.37
# Actual= 2 - Predict= 1.55 =====CORRECT=====
# Actual= 1 - Predict= 1.01 =====CORRECT=====
# Actual= 1 - Predict= 2.74
# Actual= 5 - Predict= 2.39
# Actual= 4 - Predict= 2.79
# Actual= 1 - Predict= 2.93
# Actual= 4 - Predict= 3.32
# Actual= 2 - Predict= 2.91
# Actual= 1 - Predict= 2.82
# Actual= 2 - Predict= 2.92
# Actual= 1 - Predict= 1.06 =====CORRECT=====
# Actual= 2 - Predict= 2.61
# Actual= 1 - Predict= 2.71
# Actual= 4 - Predict= 3.42
# Actual= 4 - Predict= 3.31
# Actual= 3 - Predict= 1.69
# Actual= 2 - Predict= 2.11 =====CORRECT=====
# Actual= 3 - Predict= 2.53 =====CORRECT=====
# Actual= 4 - Predict= 3.37
# Actual= 2 - Predict= 2.43 =====CORRECT=====
# Actual= 1 - Predict= 1.57
# Actual= 3 - Predict= 1.39
# Actual= 3 - Predict= 2.58 =====CORRECT=====
# Actual= 4 - Predict= 2.01
# Actual= 2 - Predict= 2.2 =====CORRECT=====
# Actual= 3 - Predict= 3.31 =====CORRECT=====
# Actual= 1 - Predict= 0.27
# Actual= 1 - Predict= 1.13 =====CORRECT=====
# Actual= 2 - Predict= 2.91
# Actual= 3 - Predict= 2.55 =====CORRECT=====
# Actual= 1 - Predict= 1.66
# Actual= 2 - Predict= 2.33 =====CORRECT=====
# Actual= 1 - Predict= 2.2
# Actual= 5 - Predict= 4.12
# Actual= 1 - Predict= 1.19 =====CORRECT=====
# Actual= 2 - Predict= 1.99 =====CORRECT=====
# Actual= 3 - Predict= 2.71 =====CORRECT=====
# Actual= 4 - Predict= 2.6
# Actual= 1 - Predict= 2.02
# Actual= 2 - Predict= 4.2
# Actual= 5 - Predict= 1.89
# Actual= 3 - Predict= 1.75
# Actual= 2 - Predict= 2.21 =====CORRECT=====
# Actual= 3 - Predict= 2.22
# Actual= 3 - Predict= 2.8 =====CORRECT=====
# Actual= 1 - Predict= 2.35
# Actual= 1 - Predict= 2.6
# Actual= 1 - Predict= 2.11
# Actual= 1 - Predict= 1.88
# Actual= 4 - Predict= 3.45
# Actual= 1 - Predict= 2.21
# Actual= 1 - Predict= 1.6
# Actual= 4 - Predict= 1.78
# Actual= 3 - Predict= 3.53
# Actual= 3 - Predict= 2.26
# Actual= 2 - Predict= 2.22 =====CORRECT=====
# Actual= 4 - Predict= 2.37
# Actual= 4 - Predict= 3.08
# Actual= 2 - Predict= 1.31
# Actual= 2 - Predict= 3.21
# Actual= 1 - Predict= 2.82
# Actual= 1 - Predict= 1.65
# Actual= 2 - Predict= 1.06
# Actual= 3 - Predict= 2.52 =====CORRECT=====
# Actual= 4 - Predict= 1.59
# Actual= 4 - Predict= 3.81 =====CORRECT=====
# Actual= 1 - Predict= 1.9
# Actual= 1 - Predict= 1.8
# Actual= 3 - Predict= 2.17
# Actual= 3 - Predict= 3.39 =====CORRECT=====
# Actual= 1 - Predict= 1.88
# Actual= 2 - Predict= 1.91 =====CORRECT=====
# Actual= 2 - Predict= 1.67 =====CORRECT=====
# Actual= 1 - Predict= 2.33
# Actual= 2 - Predict= 3.15
# Actual= 3 - Predict= 2.48
# Actual= 1 - Predict= 2.19
# Actual= 2 - Predict= 2.5 =====CORRECT=====
# Actual= 1 - Predict= 2.42
# Actual= 2 - Predict= 2.48 =====CORRECT=====
# Actual= 3 - Predict= 2.09
#
# Linear Regression had an accuracy of 0.3142857142857143
#
# ===== Ridge =====
#
# Actual= 4 - Predict= 1.99
# Actual= 1 - Predict= 2.71
# Actual= 1 - Predict= 1.16 =====CORRECT=====
# Actual= 1 - Predict= 2.34
# Actual= 2 - Predict= 2.56
# Actual= 2 - Predict= 1.7 =====CORRECT=====
# Actual= 3 - Predict= 1.99
# Actual= 3 - Predict= 2.22
# Actual= 2 - Predict= 1.43
# Actual= 2 - Predict= 2.05 =====CORRECT=====
# Actual= 1 - Predict= 2.35
# Actual= 4 - Predict= 3.58 =====CORRECT=====
# Actual= 3 - Predict= 2.41
# Actual= 1 - Predict= 1.42 =====CORRECT=====
# Actual= 2 - Predict= 2.21 =====CORRECT=====
# Actual= 2 - Predict= 2.25 =====CORRECT=====
# Actual= 1 - Predict= 2.19
# Actual= 4 - Predict= 3.07
# Actual= 2 - Predict= 2.91
# Actual= 2 - Predict= 2.06 =====CORRECT=====
# Actual= 3 - Predict= 2.06
# Actual= 4 - Predict= 3.32
# Actual= 2 - Predict= 2.62
# Actual= 2 - Predict= 1.38
# Actual= 2 - Predict= 1.55 =====CORRECT=====
# Actual= 1 - Predict= 1.01 =====CORRECT=====
# Actual= 1 - Predict= 2.73
# Actual= 5 - Predict= 2.38
# Actual= 4 - Predict= 2.79
# Actual= 1 - Predict= 2.92
# Actual= 4 - Predict= 3.32
# Actual= 2 - Predict= 2.91
# Actual= 1 - Predict= 2.82
# Actual= 2 - Predict= 2.92
# Actual= 1 - Predict= 1.06 =====CORRECT=====
# Actual= 2 - Predict= 2.6
# Actual= 1 - Predict= 2.71
# Actual= 4 - Predict= 3.42
# Actual= 4 - Predict= 3.31
# Actual= 3 - Predict= 1.69
# Actual= 2 - Predict= 2.12 =====CORRECT=====
# Actual= 3 - Predict= 2.53 =====CORRECT=====
# Actual= 4 - Predict= 3.37
# Actual= 2 - Predict= 2.43 =====CORRECT=====
# Actual= 1 - Predict= 1.58
# Actual= 3 - Predict= 1.39
# Actual= 3 - Predict= 2.58 =====CORRECT=====
# Actual= 4 - Predict= 2.02
# Actual= 2 - Predict= 2.19 =====CORRECT=====
# Actual= 3 - Predict= 3.31 =====CORRECT=====
# Actual= 1 - Predict= 0.28
# Actual= 1 - Predict= 1.13 =====CORRECT=====
# Actual= 2 - Predict= 2.91
# Actual= 3 - Predict= 2.55 =====CORRECT=====
# Actual= 1 - Predict= 1.67
# Actual= 2 - Predict= 2.33 =====CORRECT=====
# Actual= 1 - Predict= 2.2
# Actual= 5 - Predict= 4.11
# Actual= 1 - Predict= 1.19 =====CORRECT=====
# Actual= 2 - Predict= 1.99 =====CORRECT=====
# Actual= 3 - Predict= 2.71 =====CORRECT=====
# Actual= 4 - Predict= 2.6
# Actual= 1 - Predict= 2.01
# Actual= 2 - Predict= 4.2
# Actual= 5 - Predict= 1.9
# Actual= 3 - Predict= 1.75
# Actual= 2 - Predict= 2.21 =====CORRECT=====
# Actual= 3 - Predict= 2.21
# Actual= 3 - Predict= 2.81 =====CORRECT=====
# Actual= 1 - Predict= 2.34
# Actual= 1 - Predict= 2.6
# Actual= 1 - Predict= 2.11
# Actual= 1 - Predict= 1.88
# Actual= 4 - Predict= 3.44
# Actual= 1 - Predict= 2.21
# Actual= 1 - Predict= 1.6
# Actual= 4 - Predict= 1.79
# Actual= 3 - Predict= 3.52
# Actual= 3 - Predict= 2.27
# Actual= 2 - Predict= 2.22 =====CORRECT=====
# Actual= 4 - Predict= 2.37
# Actual= 4 - Predict= 3.08
# Actual= 2 - Predict= 1.32
# Actual= 2 - Predict= 3.21
# Actual= 1 - Predict= 2.82
# Actual= 1 - Predict= 1.65
# Actual= 2 - Predict= 1.06
# Actual= 3 - Predict= 2.52 =====CORRECT=====
# Actual= 4 - Predict= 1.59
# Actual= 4 - Predict= 3.81 =====CORRECT=====
# Actual= 1 - Predict= 1.89
# Actual= 1 - Predict= 1.8
# Actual= 3 - Predict= 2.17
# Actual= 3 - Predict= 3.39 =====CORRECT=====
# Actual= 1 - Predict= 1.88
# Actual= 2 - Predict= 1.91 =====CORRECT=====
# Actual= 2 - Predict= 1.67 =====CORRECT=====
# Actual= 1 - Predict= 2.33
# Actual= 2 - Predict= 3.14
# Actual= 3 - Predict= 2.49
# Actual= 1 - Predict= 2.19
# Actual= 2 - Predict= 2.5 =====CORRECT=====
# Actual= 1 - Predict= 2.42
# Actual= 2 - Predict= 2.48 =====CORRECT=====
# Actual= 3 - Predict= 2.09
#
# Ridge had an accuracy of 0.3142857142857143
#
# ===== Lasso =====
#
# Actual= 4 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 2 - Predict= 2.3 =====CORRECT=====
# Actual= 3 - Predict= 2.28
# Actual= 3 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.28
# Actual= 4 - Predict= 2.3
# Actual= 3 - Predict= 2.29
# Actual= 1 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.28
# Actual= 4 - Predict= 2.29
# Actual= 2 - Predict= 2.29 =====CORRECT=====
# Actual= 2 - Predict= 2.29 =====CORRECT=====
# Actual= 3 - Predict= 2.28
# Actual= 4 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 5 - Predict= 2.29
# Actual= 4 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 4 - Predict= 2.29
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.29
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.29
# Actual= 4 - Predict= 2.29
# Actual= 4 - Predict= 2.3
# Actual= 3 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 3 - Predict= 2.28
# Actual= 4 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.28
# Actual= 3 - Predict= 2.28
# Actual= 3 - Predict= 2.29
# Actual= 4 - Predict= 2.29
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 3 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 3 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.28
# Actual= 5 - Predict= 2.29
# Actual= 1 - Predict= 2.29
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 3 - Predict= 2.29
# Actual= 4 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 5 - Predict= 2.28
# Actual= 3 - Predict= 2.29
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 3 - Predict= 2.29
# Actual= 3 - Predict= 2.29
# Actual= 1 - Predict= 2.29
# Actual= 1 - Predict= 2.28
# Actual= 1 - Predict= 2.29
# Actual= 1 - Predict= 2.28
# Actual= 4 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 4 - Predict= 2.28
# Actual= 3 - Predict= 2.28
# Actual= 3 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 4 - Predict= 2.28
# Actual= 4 - Predict= 2.29
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 3 - Predict= 2.28
# Actual= 4 - Predict= 2.29
# Actual= 4 - Predict= 2.29
# Actual= 1 - Predict= 2.29
# Actual= 1 - Predict= 2.29
# Actual= 3 - Predict= 2.28
# Actual= 3 - Predict= 2.29
# Actual= 1 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 3 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 3 - Predict= 2.28
#
# Lasso had an accuracy of 0.29523809523809524
#
# ===== ElasticNet =====
#
# Actual= 4 - Predict= 2.36
# Actual= 1 - Predict= 2.26
# Actual= 1 - Predict= 1.69
# Actual= 1 - Predict= 2.34
# Actual= 2 - Predict= 2.51
# Actual= 2 - Predict= 2.15 =====CORRECT=====
# Actual= 3 - Predict= 2.32
# Actual= 3 - Predict= 2.26
# Actual= 2 - Predict= 1.88 =====CORRECT=====
# Actual= 2 - Predict= 2.16 =====CORRECT=====
# Actual= 1 - Predict= 2.21
# Actual= 4 - Predict= 2.98
# Actual= 3 - Predict= 2.27
# Actual= 1 - Predict= 2.02
# Actual= 2 - Predict= 2.15 =====CORRECT=====
# Actual= 2 - Predict= 2.35 =====CORRECT=====
# Actual= 1 - Predict= 2.5
# Actual= 4 - Predict= 2.45
# Actual= 2 - Predict= 2.61
# Actual= 2 - Predict= 2.53
# Actual= 3 - Predict= 2.31
# Actual= 4 - Predict= 2.58
# Actual= 2 - Predict= 2.74
# Actual= 2 - Predict= 2.12 =====CORRECT=====
# Actual= 2 - Predict= 1.9 =====CORRECT=====
# Actual= 1 - Predict= 1.68
# Actual= 1 - Predict= 2.31
# Actual= 5 - Predict= 2.37
# Actual= 4 - Predict= 2.32
# Actual= 1 - Predict= 2.38
# Actual= 4 - Predict= 2.74
# Actual= 2 - Predict= 2.69
# Actual= 1 - Predict= 2.76
# Actual= 2 - Predict= 2.41 =====CORRECT=====
# Actual= 1 - Predict= 1.62
# Actual= 2 - Predict= 2.1 =====CORRECT=====
# Actual= 1 - Predict= 2.89
# Actual= 4 - Predict= 3.08
# Actual= 4 - Predict= 3.14
# Actual= 3 - Predict= 2.09
# Actual= 2 - Predict= 2.31 =====CORRECT=====
# Actual= 3 - Predict= 2.7 =====CORRECT=====
# Actual= 4 - Predict= 2.48
# Actual= 2 - Predict= 2.12 =====CORRECT=====
# Actual= 1 - Predict= 2.11
# Actual= 3 - Predict= 1.75
# Actual= 3 - Predict= 2.35
# Actual= 4 - Predict= 2.48
# Actual= 2 - Predict= 2.2 =====CORRECT=====
# Actual= 3 - Predict= 2.59 =====CORRECT=====
# Actual= 1 - Predict= 1.65
# Actual= 1 - Predict= 1.58
# Actual= 2 - Predict= 2.22 =====CORRECT=====
# Actual= 3 - Predict= 2.29
# Actual= 1 - Predict= 2.06
# Actual= 2 - Predict= 1.91 =====CORRECT=====
# Actual= 1 - Predict= 2.27
# Actual= 5 - Predict= 3.32
# Actual= 1 - Predict= 2.04
# Actual= 2 - Predict= 1.97 =====CORRECT=====
# Actual= 3 - Predict= 2.44
# Actual= 4 - Predict= 2.13
# Actual= 1 - Predict= 2.17
# Actual= 2 - Predict= 3.13
# Actual= 5 - Predict= 2.24
# Actual= 3 - Predict= 2.22
# Actual= 2 - Predict= 1.89 =====CORRECT=====
# Actual= 3 - Predict= 2.48
# Actual= 3 - Predict= 3.1 =====CORRECT=====
# Actual= 1 - Predict= 2.07
# Actual= 1 - Predict= 2.24
# Actual= 1 - Predict= 2.38
# Actual= 1 - Predict= 2.28
# Actual= 4 - Predict= 2.86
# Actual= 1 - Predict= 2.13
# Actual= 1 - Predict= 2.09
# Actual= 4 - Predict= 2.22
# Actual= 3 - Predict= 2.43
# Actual= 3 - Predict= 2.46
# Actual= 2 - Predict= 2.08 =====CORRECT=====
# Actual= 4 - Predict= 2.1
# Actual= 4 - Predict= 2.69
# Actual= 2 - Predict= 2.04 =====CORRECT=====
# Actual= 2 - Predict= 3.06
# Actual= 1 - Predict= 2.8
# Actual= 1 - Predict= 2.09
# Actual= 2 - Predict= 1.98 =====CORRECT=====
# Actual= 3 - Predict= 2.48
# Actual= 4 - Predict= 2.12
# Actual= 4 - Predict= 3.04
# Actual= 1 - Predict= 2.13
# Actual= 1 - Predict= 2.02
# Actual= 3 - Predict= 2.71 =====CORRECT=====
# Actual= 3 - Predict= 3.09 =====CORRECT=====
# Actual= 1 - Predict= 1.91
# Actual= 2 - Predict= 2.26 =====CORRECT=====
# Actual= 2 - Predict= 1.96 =====CORRECT=====
# Actual= 1 - Predict= 2.47
# Actual= 2 - Predict= 2.48 =====CORRECT=====
# Actual= 3 - Predict= 2.38
# Actual= 1 - Predict= 2.18
# Actual= 2 - Predict= 2.2 =====CORRECT=====
# Actual= 1 - Predict= 2.58
# Actual= 2 - Predict= 2.27 =====CORRECT=====
# Actual= 3 - Predict= 2.12
#
# ElasticNet had an accuracy of 0.2761904761904762

# %%
# Finding optimal parameters for every method

# Linear Regression

grid_params = {
    'fit_intercept': ['True', 'False', 'optional']
}

gs_1 = GridSearchCV(LinearRegression(), grid_params)
gs_1 = gs_1.fit(X, y)
print("Best hyperparameter: fit_intercept: {}\n".format(gs_1.best_params_.get('fit_intercept')))

# Ridge

grid_params = {
    'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg']
}

gs_1 = GridSearchCV(Ridge(), grid_params)
gs_1 = gs_1.fit(X, y)
print("Best hyperparameter: solver: {}\n".format(gs_1.best_params_.get('solver')))

# Lasso

grid_params = {
    'normalize': [True, False, 'optional'] 
}

gs_1 = GridSearchCV(Lasso(), grid_params)
gs_1 = gs_1.fit(X, y)
print("Best hyperparameter: normalize: {}\n".format(gs_1.best_params_.get('normalize')))

# ElasticNet

grid_params = {
    'normalize': [True, False, 'optional'] 
}

gs_1 = GridSearchCV(ElasticNet(), grid_params)
gs_1 = gs_1.fit(X, y)
print("Best hyperparameter: normalize: {}\n".format(gs_1.best_params_.get('normalize')))
# Out:
# Best hyperparameter: fit_intercept: True
#
# Best hyperparameter: solver: lsqr
#
# Best hyperparameter: normalize: False
#
# Best hyperparameter: normalize: False

# %%
# Predictions with optimal parameters

lm = LinearRegression()
lm_fit = lm.fit(X_train, y_train)

ridge = Ridge(solver='lsqr')
ridge_fit = ridge.fit(X_train,y_train)

lasso = Lasso(max_iter=1000, normalize=False)
lasso_fit = lasso.fit(X_train,y_train)

ENet = ElasticNet(l1_ratio=.01, normalize=False)
ENet_fit = ENet.fit(X_train,y_train)

preds = [[lm_fit, 'Linear Regression'], [ridge_fit, 'Ridge'], [lasso_fit, 'Lasso'], [ENet_fit, 'ElasticNet']]


# Comparing predicted y to the actual y and calculating the average

param_results  = []

for p in preds:
    correct = 0
    print("===== {} =====".format(p[1]))
    print()
    for i in range(len(X_test)):
        a = p[0].predict([X_test.iloc[i]])
        msg = ""
        # The predicted values are rounded since they need to be either 1, 2, 3, 4 or 5
        if y_test.values[i] == np.around(a[0]):
            msg = "=====CORRECT====="
            correct += 1
        print("Actual= {} - Predict= {} {}".format(y_test.values[i],round(a[0],2), msg))
    print()
    print("{} had an accuracy of {}".format(p[1], correct/len(X_test)))
    param_results.append([p[1], correct/len(X_test)])
    print()
# Out:
# ===== Linear Regression =====
#
# Actual= 4 - Predict= 1.99
# Actual= 1 - Predict= 2.72
# Actual= 1 - Predict= 1.16 =====CORRECT=====
# Actual= 1 - Predict= 2.34
# Actual= 2 - Predict= 2.56
# Actual= 2 - Predict= 1.69 =====CORRECT=====
# Actual= 3 - Predict= 1.99
# Actual= 3 - Predict= 2.21
# Actual= 2 - Predict= 1.43
# Actual= 2 - Predict= 2.05 =====CORRECT=====
# Actual= 1 - Predict= 2.36
# Actual= 4 - Predict= 3.58 =====CORRECT=====
# Actual= 3 - Predict= 2.42
# Actual= 1 - Predict= 1.42 =====CORRECT=====
# Actual= 2 - Predict= 2.21 =====CORRECT=====
# Actual= 2 - Predict= 2.25 =====CORRECT=====
# Actual= 1 - Predict= 2.19
# Actual= 4 - Predict= 3.08
# Actual= 2 - Predict= 2.92
# Actual= 2 - Predict= 2.05 =====CORRECT=====
# Actual= 3 - Predict= 2.06
# Actual= 4 - Predict= 3.33
# Actual= 2 - Predict= 2.62
# Actual= 2 - Predict= 1.37
# Actual= 2 - Predict= 1.55 =====CORRECT=====
# Actual= 1 - Predict= 1.01 =====CORRECT=====
# Actual= 1 - Predict= 2.74
# Actual= 5 - Predict= 2.39
# Actual= 4 - Predict= 2.79
# Actual= 1 - Predict= 2.93
# Actual= 4 - Predict= 3.32
# Actual= 2 - Predict= 2.91
# Actual= 1 - Predict= 2.82
# Actual= 2 - Predict= 2.92
# Actual= 1 - Predict= 1.06 =====CORRECT=====
# Actual= 2 - Predict= 2.61
# Actual= 1 - Predict= 2.71
# Actual= 4 - Predict= 3.42
# Actual= 4 - Predict= 3.31
# Actual= 3 - Predict= 1.69
# Actual= 2 - Predict= 2.11 =====CORRECT=====
# Actual= 3 - Predict= 2.53 =====CORRECT=====
# Actual= 4 - Predict= 3.37
# Actual= 2 - Predict= 2.43 =====CORRECT=====
# Actual= 1 - Predict= 1.57
# Actual= 3 - Predict= 1.39
# Actual= 3 - Predict= 2.58 =====CORRECT=====
# Actual= 4 - Predict= 2.01
# Actual= 2 - Predict= 2.2 =====CORRECT=====
# Actual= 3 - Predict= 3.31 =====CORRECT=====
# Actual= 1 - Predict= 0.27
# Actual= 1 - Predict= 1.13 =====CORRECT=====
# Actual= 2 - Predict= 2.91
# Actual= 3 - Predict= 2.55 =====CORRECT=====
# Actual= 1 - Predict= 1.66
# Actual= 2 - Predict= 2.33 =====CORRECT=====
# Actual= 1 - Predict= 2.2
# Actual= 5 - Predict= 4.12
# Actual= 1 - Predict= 1.19 =====CORRECT=====
# Actual= 2 - Predict= 1.99 =====CORRECT=====
# Actual= 3 - Predict= 2.71 =====CORRECT=====
# Actual= 4 - Predict= 2.6
# Actual= 1 - Predict= 2.02
# Actual= 2 - Predict= 4.2
# Actual= 5 - Predict= 1.89
# Actual= 3 - Predict= 1.75
# Actual= 2 - Predict= 2.21 =====CORRECT=====
# Actual= 3 - Predict= 2.22
# Actual= 3 - Predict= 2.8 =====CORRECT=====
# Actual= 1 - Predict= 2.35
# Actual= 1 - Predict= 2.6
# Actual= 1 - Predict= 2.11
# Actual= 1 - Predict= 1.88
# Actual= 4 - Predict= 3.45
# Actual= 1 - Predict= 2.21
# Actual= 1 - Predict= 1.6
# Actual= 4 - Predict= 1.78
# Actual= 3 - Predict= 3.53
# Actual= 3 - Predict= 2.26
# Actual= 2 - Predict= 2.22 =====CORRECT=====
# Actual= 4 - Predict= 2.37
# Actual= 4 - Predict= 3.08
# Actual= 2 - Predict= 1.31
# Actual= 2 - Predict= 3.21
# Actual= 1 - Predict= 2.82
# Actual= 1 - Predict= 1.65
# Actual= 2 - Predict= 1.06
# Actual= 3 - Predict= 2.52 =====CORRECT=====
# Actual= 4 - Predict= 1.59
# Actual= 4 - Predict= 3.81 =====CORRECT=====
# Actual= 1 - Predict= 1.9
# Actual= 1 - Predict= 1.8
# Actual= 3 - Predict= 2.17
# Actual= 3 - Predict= 3.39 =====CORRECT=====
# Actual= 1 - Predict= 1.88
# Actual= 2 - Predict= 1.91 =====CORRECT=====
# Actual= 2 - Predict= 1.67 =====CORRECT=====
# Actual= 1 - Predict= 2.33
# Actual= 2 - Predict= 3.15
# Actual= 3 - Predict= 2.48
# Actual= 1 - Predict= 2.19
# Actual= 2 - Predict= 2.5 =====CORRECT=====
# Actual= 1 - Predict= 2.42
# Actual= 2 - Predict= 2.48 =====CORRECT=====
# Actual= 3 - Predict= 2.09
#
# Linear Regression had an accuracy of 0.3142857142857143
#
# ===== Ridge =====
#
# Actual= 4 - Predict= 1.98
# Actual= 1 - Predict= 2.73
# Actual= 1 - Predict= 1.13 =====CORRECT=====
# Actual= 1 - Predict= 2.31
# Actual= 2 - Predict= 2.62
# Actual= 2 - Predict= 1.69 =====CORRECT=====
# Actual= 3 - Predict= 2.03
# Actual= 3 - Predict= 2.25
# Actual= 2 - Predict= 1.42
# Actual= 2 - Predict= 2.03 =====CORRECT=====
# Actual= 1 - Predict= 2.33
# Actual= 4 - Predict= 3.55 =====CORRECT=====
# Actual= 3 - Predict= 2.41
# Actual= 1 - Predict= 1.44 =====CORRECT=====
# Actual= 2 - Predict= 2.18 =====CORRECT=====
# Actual= 2 - Predict= 2.25 =====CORRECT=====
# Actual= 1 - Predict= 2.17
# Actual= 4 - Predict= 3.07
# Actual= 2 - Predict= 2.94
# Actual= 2 - Predict= 2.08 =====CORRECT=====
# Actual= 3 - Predict= 2.06
# Actual= 4 - Predict= 3.32
# Actual= 2 - Predict= 2.6
# Actual= 2 - Predict= 1.38
# Actual= 2 - Predict= 1.51 =====CORRECT=====
# Actual= 1 - Predict= 1.01 =====CORRECT=====
# Actual= 1 - Predict= 2.76
# Actual= 5 - Predict= 2.39
# Actual= 4 - Predict= 2.77
# Actual= 1 - Predict= 2.95
# Actual= 4 - Predict= 3.36
# Actual= 2 - Predict= 2.86
# Actual= 1 - Predict= 2.84
# Actual= 2 - Predict= 2.91
# Actual= 1 - Predict= 1.06 =====CORRECT=====
# Actual= 2 - Predict= 2.6
# Actual= 1 - Predict= 2.67
# Actual= 4 - Predict= 3.41
# Actual= 4 - Predict= 3.29
# Actual= 3 - Predict= 1.67
# Actual= 2 - Predict= 2.11 =====CORRECT=====
# Actual= 3 - Predict= 2.53 =====CORRECT=====
# Actual= 4 - Predict= 3.41
# Actual= 2 - Predict= 2.42 =====CORRECT=====
# Actual= 1 - Predict= 1.64
# Actual= 3 - Predict= 1.39
# Actual= 3 - Predict= 2.55 =====CORRECT=====
# Actual= 4 - Predict= 1.98
# Actual= 2 - Predict= 2.17 =====CORRECT=====
# Actual= 3 - Predict= 3.32 =====CORRECT=====
# Actual= 1 - Predict= 0.28
# Actual= 1 - Predict= 1.09 =====CORRECT=====
# Actual= 2 - Predict= 2.89
# Actual= 3 - Predict= 2.58 =====CORRECT=====
# Actual= 1 - Predict= 1.66
# Actual= 2 - Predict= 2.34 =====CORRECT=====
# Actual= 1 - Predict= 2.18
# Actual= 5 - Predict= 4.08
# Actual= 1 - Predict= 1.18 =====CORRECT=====
# Actual= 2 - Predict= 2.0 =====CORRECT=====
# Actual= 3 - Predict= 2.69 =====CORRECT=====
# Actual= 4 - Predict= 2.61
# Actual= 1 - Predict= 1.97
# Actual= 2 - Predict= 4.19
# Actual= 5 - Predict= 1.92
# Actual= 3 - Predict= 1.75
# Actual= 2 - Predict= 2.21 =====CORRECT=====
# Actual= 3 - Predict= 2.18
# Actual= 3 - Predict= 2.8 =====CORRECT=====
# Actual= 1 - Predict= 2.36
# Actual= 1 - Predict= 2.6
# Actual= 1 - Predict= 2.1
# Actual= 1 - Predict= 1.89
# Actual= 4 - Predict= 3.41
# Actual= 1 - Predict= 2.24
# Actual= 1 - Predict= 1.59
# Actual= 4 - Predict= 1.8
# Actual= 3 - Predict= 3.48 =====CORRECT=====
# Actual= 3 - Predict= 2.36
# Actual= 2 - Predict= 2.22 =====CORRECT=====
# Actual= 4 - Predict= 2.4
# Actual= 4 - Predict= 3.06
# Actual= 2 - Predict= 1.32
# Actual= 2 - Predict= 3.18
# Actual= 1 - Predict= 2.81
# Actual= 1 - Predict= 1.64
# Actual= 2 - Predict= 1.07
# Actual= 3 - Predict= 2.51 =====CORRECT=====
# Actual= 4 - Predict= 1.56
# Actual= 4 - Predict= 3.75 =====CORRECT=====
# Actual= 1 - Predict= 1.9
# Actual= 1 - Predict= 1.78
# Actual= 3 - Predict= 2.16
# Actual= 3 - Predict= 3.4 =====CORRECT=====
# Actual= 1 - Predict= 1.88
# Actual= 2 - Predict= 1.94 =====CORRECT=====
# Actual= 2 - Predict= 1.66 =====CORRECT=====
# Actual= 1 - Predict= 2.35
# Actual= 2 - Predict= 3.14
# Actual= 3 - Predict= 2.51 =====CORRECT=====
# Actual= 1 - Predict= 2.22
# Actual= 2 - Predict= 2.5 =====CORRECT=====
# Actual= 1 - Predict= 2.45
# Actual= 2 - Predict= 2.5 =====CORRECT=====
# Actual= 3 - Predict= 2.09
#
# Ridge had an accuracy of 0.3333333333333333
#
# ===== Lasso =====
#
# Actual= 4 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 2 - Predict= 2.3 =====CORRECT=====
# Actual= 3 - Predict= 2.28
# Actual= 3 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.28
# Actual= 4 - Predict= 2.3
# Actual= 3 - Predict= 2.29
# Actual= 1 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.28
# Actual= 4 - Predict= 2.29
# Actual= 2 - Predict= 2.29 =====CORRECT=====
# Actual= 2 - Predict= 2.29 =====CORRECT=====
# Actual= 3 - Predict= 2.28
# Actual= 4 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 5 - Predict= 2.29
# Actual= 4 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 4 - Predict= 2.29
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.29
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.29
# Actual= 4 - Predict= 2.29
# Actual= 4 - Predict= 2.3
# Actual= 3 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 3 - Predict= 2.28
# Actual= 4 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.28
# Actual= 3 - Predict= 2.28
# Actual= 3 - Predict= 2.29
# Actual= 4 - Predict= 2.29
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 3 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 3 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.28
# Actual= 5 - Predict= 2.29
# Actual= 1 - Predict= 2.29
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 3 - Predict= 2.29
# Actual= 4 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 5 - Predict= 2.28
# Actual= 3 - Predict= 2.29
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 3 - Predict= 2.29
# Actual= 3 - Predict= 2.29
# Actual= 1 - Predict= 2.29
# Actual= 1 - Predict= 2.28
# Actual= 1 - Predict= 2.29
# Actual= 1 - Predict= 2.28
# Actual= 4 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 4 - Predict= 2.28
# Actual= 3 - Predict= 2.28
# Actual= 3 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 4 - Predict= 2.28
# Actual= 4 - Predict= 2.29
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 3 - Predict= 2.28
# Actual= 4 - Predict= 2.29
# Actual= 4 - Predict= 2.29
# Actual= 1 - Predict= 2.29
# Actual= 1 - Predict= 2.29
# Actual= 3 - Predict= 2.28
# Actual= 3 - Predict= 2.29
# Actual= 1 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 3 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 3 - Predict= 2.28
#
# Lasso had an accuracy of 0.29523809523809524
#
# ===== ElasticNet =====
#
# Actual= 4 - Predict= 2.36
# Actual= 1 - Predict= 2.26
# Actual= 1 - Predict= 1.69
# Actual= 1 - Predict= 2.34
# Actual= 2 - Predict= 2.51
# Actual= 2 - Predict= 2.15 =====CORRECT=====
# Actual= 3 - Predict= 2.32
# Actual= 3 - Predict= 2.26
# Actual= 2 - Predict= 1.88 =====CORRECT=====
# Actual= 2 - Predict= 2.16 =====CORRECT=====
# Actual= 1 - Predict= 2.21
# Actual= 4 - Predict= 2.98
# Actual= 3 - Predict= 2.27
# Actual= 1 - Predict= 2.02
# Actual= 2 - Predict= 2.15 =====CORRECT=====
# Actual= 2 - Predict= 2.35 =====CORRECT=====
# Actual= 1 - Predict= 2.5
# Actual= 4 - Predict= 2.45
# Actual= 2 - Predict= 2.61
# Actual= 2 - Predict= 2.53
# Actual= 3 - Predict= 2.31
# Actual= 4 - Predict= 2.58
# Actual= 2 - Predict= 2.74
# Actual= 2 - Predict= 2.12 =====CORRECT=====
# Actual= 2 - Predict= 1.9 =====CORRECT=====
# Actual= 1 - Predict= 1.68
# Actual= 1 - Predict= 2.31
# Actual= 5 - Predict= 2.37
# Actual= 4 - Predict= 2.32
# Actual= 1 - Predict= 2.38
# Actual= 4 - Predict= 2.74
# Actual= 2 - Predict= 2.69
# Actual= 1 - Predict= 2.76
# Actual= 2 - Predict= 2.41 =====CORRECT=====
# Actual= 1 - Predict= 1.62
# Actual= 2 - Predict= 2.1 =====CORRECT=====
# Actual= 1 - Predict= 2.89
# Actual= 4 - Predict= 3.08
# Actual= 4 - Predict= 3.14
# Actual= 3 - Predict= 2.09
# Actual= 2 - Predict= 2.31 =====CORRECT=====
# Actual= 3 - Predict= 2.7 =====CORRECT=====
# Actual= 4 - Predict= 2.48
# Actual= 2 - Predict= 2.12 =====CORRECT=====
# Actual= 1 - Predict= 2.11
# Actual= 3 - Predict= 1.75
# Actual= 3 - Predict= 2.35
# Actual= 4 - Predict= 2.48
# Actual= 2 - Predict= 2.2 =====CORRECT=====
# Actual= 3 - Predict= 2.59 =====CORRECT=====
# Actual= 1 - Predict= 1.65
# Actual= 1 - Predict= 1.58
# Actual= 2 - Predict= 2.22 =====CORRECT=====
# Actual= 3 - Predict= 2.29
# Actual= 1 - Predict= 2.06
# Actual= 2 - Predict= 1.91 =====CORRECT=====
# Actual= 1 - Predict= 2.27
# Actual= 5 - Predict= 3.32
# Actual= 1 - Predict= 2.04
# Actual= 2 - Predict= 1.97 =====CORRECT=====
# Actual= 3 - Predict= 2.44
# Actual= 4 - Predict= 2.13
# Actual= 1 - Predict= 2.17
# Actual= 2 - Predict= 3.13
# Actual= 5 - Predict= 2.24
# Actual= 3 - Predict= 2.22
# Actual= 2 - Predict= 1.89 =====CORRECT=====
# Actual= 3 - Predict= 2.48
# Actual= 3 - Predict= 3.1 =====CORRECT=====
# Actual= 1 - Predict= 2.07
# Actual= 1 - Predict= 2.24
# Actual= 1 - Predict= 2.38
# Actual= 1 - Predict= 2.28
# Actual= 4 - Predict= 2.86
# Actual= 1 - Predict= 2.13
# Actual= 1 - Predict= 2.09
# Actual= 4 - Predict= 2.22
# Actual= 3 - Predict= 2.43
# Actual= 3 - Predict= 2.46
# Actual= 2 - Predict= 2.08 =====CORRECT=====
# Actual= 4 - Predict= 2.1
# Actual= 4 - Predict= 2.69
# Actual= 2 - Predict= 2.04 =====CORRECT=====
# Actual= 2 - Predict= 3.06
# Actual= 1 - Predict= 2.8
# Actual= 1 - Predict= 2.09
# Actual= 2 - Predict= 1.98 =====CORRECT=====
# Actual= 3 - Predict= 2.48
# Actual= 4 - Predict= 2.12
# Actual= 4 - Predict= 3.04
# Actual= 1 - Predict= 2.13
# Actual= 1 - Predict= 2.02
# Actual= 3 - Predict= 2.71 =====CORRECT=====
# Actual= 3 - Predict= 3.09 =====CORRECT=====
# Actual= 1 - Predict= 1.91
# Actual= 2 - Predict= 2.26 =====CORRECT=====
# Actual= 2 - Predict= 1.96 =====CORRECT=====
# Actual= 1 - Predict= 2.47
# Actual= 2 - Predict= 2.48 =====CORRECT=====
# Actual= 3 - Predict= 2.38
# Actual= 1 - Predict= 2.18
# Actual= 2 - Predict= 2.2 =====CORRECT=====
# Actual= 1 - Predict= 2.58
# Actual= 2 - Predict= 2.27 =====CORRECT=====
# Actual= 3 - Predict= 2.12
#
# ElasticNet had an accuracy of 0.2761904761904762

# %%
# Comparing results

for a, b in zip(default_results, param_results):
    print("Default parameters  -  " + str(a))
    print("Tuned parameters  -  " + str(b))
    print()
# Out:
# Default parameters  -  ['Linear Regression', 0.3142857142857143]
# Tuned parameters  -  ['Linear Regression', 0.3142857142857143]
#
# Default parameters  -  ['Ridge', 0.3142857142857143]
# Tuned parameters  -  ['Ridge', 0.3333333333333333]
#
# Default parameters  -  ['Lasso', 0.29523809523809524]
# Tuned parameters  -  ['Lasso', 0.29523809523809524]
#
# Default parameters  -  ['ElasticNet', 0.2761904761904762]
# Tuned parameters  -  ['ElasticNet', 0.2761904761904762]

# %%
# Using only the ten most important features as explained in the EDA

best_features = ['Dalc', 'absences', 'goout','sex_M','sex_F','failures','schoolsup_yes','studytime','G1','G3']
drop = []

for f in feature_names:
    if f not in best_features:
        drop.append(f)
        
drop.append('Walc')

X = data.drop(drop,axis=1)
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=.1)

# Predicting labels again

lm = LinearRegression()
lm_fit = lm.fit(X_train, y_train)

ridge = Ridge(solver='lsqr')
ridge_fit = ridge.fit(X_train,y_train)

lasso = Lasso(max_iter=1000)
lasso_fit = lasso.fit(X_train,y_train)

ENet = ElasticNet(l1_ratio=.01)
ENet_fit = ENet.fit(X_train,y_train)

preds = [[lm_fit, 'Linear Regression'], [ridge_fit, 'Ridge'], [lasso_fit, 'Lasso'], [ENet_fit, 'ElasticNet']]


# Comparing predicted y to the actual y and calculating the average

best_features_results  = []

for p in preds:
    correct = 0
    print("===== {} =====".format(p[1]))
    print()
    for i in range(len(X_test)):
        a = p[0].predict([X_test.iloc[i]])
        msg = ""
        # The predicted values are rounded since they need to be either 1, 2, 3, 4 or 5
        if y_test.values[i] == np.around(a[0]):
            msg = "=====CORRECT====="
            correct += 1
        print("Actual= {} - Predict= {} {}".format(y_test.values[i],round(a[0],2), msg))
    print()
    print("{} had an accuracy of {}".format(p[1], correct/len(X_test)))
    best_features_results.append([p[1], correct/len(X_test)])
    print()
# Out:
# ===== Linear Regression =====
#
# Actual= 1 - Predict= 1.19 =====CORRECT=====
# Actual= 2 - Predict= 1.41
# Actual= 2 - Predict= 2.8
# Actual= 2 - Predict= 1.54 =====CORRECT=====
# Actual= 1 - Predict= 1.86
# Actual= 1 - Predict= 1.98
# Actual= 2 - Predict= 1.83 =====CORRECT=====
# Actual= 4 - Predict= 2.75
# Actual= 1 - Predict= 0.83 =====CORRECT=====
# Actual= 3 - Predict= 2.48
# Actual= 2 - Predict= 2.09 =====CORRECT=====
# Actual= 2 - Predict= 2.04 =====CORRECT=====
# Actual= 3 - Predict= 2.26
# Actual= 3 - Predict= 2.2
# Actual= 1 - Predict= 1.89
# Actual= 4 - Predict= 4.21 =====CORRECT=====
# Actual= 4 - Predict= 2.16
# Actual= 4 - Predict= 3.86 =====CORRECT=====
# Actual= 1 - Predict= 1.48 =====CORRECT=====
# Actual= 1 - Predict= 1.55
# Actual= 2 - Predict= 2.58
# Actual= 4 - Predict= 2.98
# Actual= 3 - Predict= 2.15
# Actual= 2 - Predict= 2.3 =====CORRECT=====
# Actual= 3 - Predict= 1.41
# Actual= 3 - Predict= 1.93
# Actual= 4 - Predict= 2.2
# Actual= 5 - Predict= 3.97
# Actual= 3 - Predict= 2.85 =====CORRECT=====
# Actual= 1 - Predict= 0.94 =====CORRECT=====
# Actual= 2 - Predict= 2.3 =====CORRECT=====
# Actual= 3 - Predict= 1.55
# Actual= 3 - Predict= 2.55 =====CORRECT=====
# Actual= 3 - Predict= 1.6
# Actual= 2 - Predict= 2.4 =====CORRECT=====
# Actual= 1 - Predict= 1.42 =====CORRECT=====
# Actual= 2 - Predict= 1.89 =====CORRECT=====
# Actual= 5 - Predict= 2.22
# Actual= 3 - Predict= 1.98
# Actual= 1 - Predict= 2.32
# Actual= 3 - Predict= 2.07
# Actual= 3 - Predict= 2.02
# Actual= 4 - Predict= 3.13
# Actual= 1 - Predict= 1.72
# Actual= 1 - Predict= 1.91
# Actual= 1 - Predict= 1.12 =====CORRECT=====
# Actual= 1 - Predict= 0.65 =====CORRECT=====
# Actual= 1 - Predict= 1.75
# Actual= 3 - Predict= 1.5
# Actual= 1 - Predict= 2.25
# Actual= 3 - Predict= 2.88 =====CORRECT=====
# Actual= 1 - Predict= 1.74
# Actual= 4 - Predict= 2.38
# Actual= 5 - Predict= 3.43
# Actual= 2 - Predict= 2.79
# Actual= 1 - Predict= 1.67
# Actual= 2 - Predict= 3.14
# Actual= 1 - Predict= 1.17 =====CORRECT=====
# Actual= 2 - Predict= 1.3
# Actual= 2 - Predict= 1.81 =====CORRECT=====
# Actual= 4 - Predict= 2.39
# Actual= 4 - Predict= 1.78
# Actual= 3 - Predict= 1.58
# Actual= 1 - Predict= 1.46 =====CORRECT=====
# Actual= 2 - Predict= 2.26 =====CORRECT=====
# Actual= 1 - Predict= 1.34 =====CORRECT=====
# Actual= 3 - Predict= 1.9
# Actual= 3 - Predict= 4.42
# Actual= 5 - Predict= 2.55
# Actual= 5 - Predict= 4.86 =====CORRECT=====
# Actual= 3 - Predict= 2.24
# Actual= 1 - Predict= 1.02 =====CORRECT=====
# Actual= 3 - Predict= 3.65
# Actual= 1 - Predict= 1.53
# Actual= 3 - Predict= 1.79
# Actual= 1 - Predict= 1.73
# Actual= 2 - Predict= 1.66 =====CORRECT=====
# Actual= 1 - Predict= 1.17 =====CORRECT=====
# Actual= 3 - Predict= 2.41
# Actual= 4 - Predict= 2.29
# Actual= 1 - Predict= 2.22
# Actual= 5 - Predict= 2.59
# Actual= 4 - Predict= 3.78 =====CORRECT=====
# Actual= 3 - Predict= 2.22
# Actual= 1 - Predict= 2.12
# Actual= 2 - Predict= 2.07 =====CORRECT=====
# Actual= 1 - Predict= 1.59
# Actual= 1 - Predict= 2.46
# Actual= 1 - Predict= 1.3 =====CORRECT=====
# Actual= 4 - Predict= 4.08 =====CORRECT=====
# Actual= 2 - Predict= 1.76 =====CORRECT=====
# Actual= 1 - Predict= 1.85
# Actual= 2 - Predict= 1.61 =====CORRECT=====
# Actual= 2 - Predict= 2.81
# Actual= 1 - Predict= 2.38
# Actual= 3 - Predict= 2.26
# Actual= 4 - Predict= 1.64
# Actual= 1 - Predict= 2.19
# Actual= 1 - Predict= 1.37 =====CORRECT=====
# Actual= 1 - Predict= 2.28
# Actual= 3 - Predict= 1.97
# Actual= 1 - Predict= 1.81
# Actual= 2 - Predict= 1.32
# Actual= 2 - Predict= 2.18 =====CORRECT=====
# Actual= 1 - Predict= 1.6
#
# Linear Regression had an accuracy of 0.3523809523809524
#
# ===== Ridge =====
#
# Actual= 1 - Predict= 1.18 =====CORRECT=====
# Actual= 2 - Predict= 1.39
# Actual= 2 - Predict= 2.79
# Actual= 2 - Predict= 1.52 =====CORRECT=====
# Actual= 1 - Predict= 1.89
# Actual= 1 - Predict= 1.97
# Actual= 2 - Predict= 1.82 =====CORRECT=====
# Actual= 4 - Predict= 2.74
# Actual= 1 - Predict= 0.82 =====CORRECT=====
# Actual= 3 - Predict= 2.47
# Actual= 2 - Predict= 2.08 =====CORRECT=====
# Actual= 2 - Predict= 2.05 =====CORRECT=====
# Actual= 3 - Predict= 2.27
# Actual= 3 - Predict= 2.21
# Actual= 1 - Predict= 1.88
# Actual= 4 - Predict= 4.21 =====CORRECT=====
# Actual= 4 - Predict= 2.14
# Actual= 4 - Predict= 3.86 =====CORRECT=====
# Actual= 1 - Predict= 1.47 =====CORRECT=====
# Actual= 1 - Predict= 1.54
# Actual= 2 - Predict= 2.59
# Actual= 4 - Predict= 2.98
# Actual= 3 - Predict= 2.16
# Actual= 2 - Predict= 2.3 =====CORRECT=====
# Actual= 3 - Predict= 1.4
# Actual= 3 - Predict= 1.93
# Actual= 4 - Predict= 2.19
# Actual= 5 - Predict= 3.97
# Actual= 3 - Predict= 2.86 =====CORRECT=====
# Actual= 1 - Predict= 0.92 =====CORRECT=====
# Actual= 2 - Predict= 2.3 =====CORRECT=====
# Actual= 3 - Predict= 1.59
# Actual= 3 - Predict= 2.58 =====CORRECT=====
# Actual= 3 - Predict= 1.59
# Actual= 2 - Predict= 2.43 =====CORRECT=====
# Actual= 1 - Predict= 1.41 =====CORRECT=====
# Actual= 2 - Predict= 1.88 =====CORRECT=====
# Actual= 5 - Predict= 2.22
# Actual= 3 - Predict= 1.97
# Actual= 1 - Predict= 2.31
# Actual= 3 - Predict= 2.05
# Actual= 3 - Predict= 2.03
# Actual= 4 - Predict= 3.14
# Actual= 1 - Predict= 1.7
# Actual= 1 - Predict= 1.95
# Actual= 1 - Predict= 1.15 =====CORRECT=====
# Actual= 1 - Predict= 0.68 =====CORRECT=====
# Actual= 1 - Predict= 1.75
# Actual= 3 - Predict= 1.53
# Actual= 1 - Predict= 2.26
# Actual= 3 - Predict= 2.87 =====CORRECT=====
# Actual= 1 - Predict= 1.72
# Actual= 4 - Predict= 2.38
# Actual= 5 - Predict= 3.45
# Actual= 2 - Predict= 2.79
# Actual= 1 - Predict= 1.66
# Actual= 2 - Predict= 3.14
# Actual= 1 - Predict= 1.16 =====CORRECT=====
# Actual= 2 - Predict= 1.29
# Actual= 2 - Predict= 1.81 =====CORRECT=====
# Actual= 4 - Predict= 2.42
# Actual= 4 - Predict= 1.78
# Actual= 3 - Predict= 1.56
# Actual= 1 - Predict= 1.45 =====CORRECT=====
# Actual= 2 - Predict= 2.27 =====CORRECT=====
# Actual= 1 - Predict= 1.33 =====CORRECT=====
# Actual= 3 - Predict= 1.91
# Actual= 3 - Predict= 4.39
# Actual= 5 - Predict= 2.54
# Actual= 5 - Predict= 4.86 =====CORRECT=====
# Actual= 3 - Predict= 2.24
# Actual= 1 - Predict= 1.05 =====CORRECT=====
# Actual= 3 - Predict= 3.65
# Actual= 1 - Predict= 1.52
# Actual= 3 - Predict= 1.78
# Actual= 1 - Predict= 1.72
# Actual= 2 - Predict= 1.65 =====CORRECT=====
# Actual= 1 - Predict= 1.19 =====CORRECT=====
# Actual= 3 - Predict= 2.39
# Actual= 4 - Predict= 2.3
# Actual= 1 - Predict= 2.21
# Actual= 5 - Predict= 2.59
# Actual= 4 - Predict= 3.77 =====CORRECT=====
# Actual= 3 - Predict= 2.22
# Actual= 1 - Predict= 2.13
# Actual= 2 - Predict= 2.07 =====CORRECT=====
# Actual= 1 - Predict= 1.6
# Actual= 1 - Predict= 2.45
# Actual= 1 - Predict= 1.29 =====CORRECT=====
# Actual= 4 - Predict= 4.09 =====CORRECT=====
# Actual= 2 - Predict= 1.74 =====CORRECT=====
# Actual= 1 - Predict= 1.86
# Actual= 2 - Predict= 1.6 =====CORRECT=====
# Actual= 2 - Predict= 2.8
# Actual= 1 - Predict= 2.41
# Actual= 3 - Predict= 2.25
# Actual= 4 - Predict= 1.63
# Actual= 1 - Predict= 2.2
# Actual= 1 - Predict= 1.36 =====CORRECT=====
# Actual= 1 - Predict= 2.29
# Actual= 3 - Predict= 1.96
# Actual= 1 - Predict= 1.79
# Actual= 2 - Predict= 1.3
# Actual= 2 - Predict= 2.19 =====CORRECT=====
# Actual= 1 - Predict= 1.58
#
# Ridge had an accuracy of 0.3523809523809524
#
# ===== Lasso =====
#
# Actual= 1 - Predict= 2.28
# Actual= 2 - Predict= 2.27 =====CORRECT=====
# Actual= 2 - Predict= 2.29 =====CORRECT=====
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.27
# Actual= 1 - Predict= 2.27
# Actual= 2 - Predict= 2.31 =====CORRECT=====
# Actual= 4 - Predict= 2.28
# Actual= 1 - Predict= 2.27
# Actual= 3 - Predict= 2.28
# Actual= 2 - Predict= 2.27 =====CORRECT=====
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 3 - Predict= 2.27
# Actual= 3 - Predict= 2.28
# Actual= 1 - Predict= 2.27
# Actual= 4 - Predict= 2.28
# Actual= 4 - Predict= 2.27
# Actual= 4 - Predict= 2.29
# Actual= 1 - Predict= 2.29
# Actual= 1 - Predict= 2.27
# Actual= 2 - Predict= 2.27 =====CORRECT=====
# Actual= 4 - Predict= 2.28
# Actual= 3 - Predict= 2.27
# Actual= 2 - Predict= 2.27 =====CORRECT=====
# Actual= 3 - Predict= 2.27
# Actual= 3 - Predict= 2.27
# Actual= 4 - Predict= 2.29
# Actual= 5 - Predict= 2.29
# Actual= 3 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 2 - Predict= 2.27 =====CORRECT=====
# Actual= 3 - Predict= 2.27
# Actual= 3 - Predict= 2.28
# Actual= 3 - Predict= 2.27
# Actual= 2 - Predict= 2.31 =====CORRECT=====
# Actual= 1 - Predict= 2.28
# Actual= 2 - Predict= 2.3 =====CORRECT=====
# Actual= 5 - Predict= 2.27
# Actual= 3 - Predict= 2.27
# Actual= 1 - Predict= 2.27
# Actual= 3 - Predict= 2.27
# Actual= 3 - Predict= 2.28
# Actual= 4 - Predict= 2.3
# Actual= 1 - Predict= 2.27
# Actual= 1 - Predict= 2.28
# Actual= 1 - Predict= 2.27
# Actual= 1 - Predict= 2.27
# Actual= 1 - Predict= 2.28
# Actual= 3 - Predict= 2.27
# Actual= 1 - Predict= 2.27
# Actual= 3 - Predict= 2.28
# Actual= 1 - Predict= 2.27
# Actual= 4 - Predict= 2.3
# Actual= 5 - Predict= 2.29
# Actual= 2 - Predict= 2.27 =====CORRECT=====
# Actual= 1 - Predict= 2.29
# Actual= 2 - Predict= 2.27 =====CORRECT=====
# Actual= 1 - Predict= 2.27
# Actual= 2 - Predict= 2.27 =====CORRECT=====
# Actual= 2 - Predict= 2.27 =====CORRECT=====
# Actual= 4 - Predict= 2.27
# Actual= 4 - Predict= 2.27
# Actual= 3 - Predict= 2.27
# Actual= 1 - Predict= 2.28
# Actual= 2 - Predict= 2.3 =====CORRECT=====
# Actual= 1 - Predict= 2.27
# Actual= 3 - Predict= 2.27
# Actual= 3 - Predict= 2.3
# Actual= 5 - Predict= 2.27
# Actual= 5 - Predict= 2.31
# Actual= 3 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 3 - Predict= 2.28
# Actual= 1 - Predict= 2.27
# Actual= 3 - Predict= 2.31
# Actual= 1 - Predict= 2.27
# Actual= 2 - Predict= 2.3 =====CORRECT=====
# Actual= 1 - Predict= 2.27
# Actual= 3 - Predict= 2.3
# Actual= 4 - Predict= 2.28
# Actual= 1 - Predict= 2.27
# Actual= 5 - Predict= 2.27
# Actual= 4 - Predict= 2.27
# Actual= 3 - Predict= 2.29
# Actual= 1 - Predict= 2.27
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.3
# Actual= 1 - Predict= 2.27
# Actual= 1 - Predict= 2.28
# Actual= 4 - Predict= 2.31
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.27
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 2 - Predict= 2.27 =====CORRECT=====
# Actual= 1 - Predict= 2.35
# Actual= 3 - Predict= 2.3
# Actual= 4 - Predict= 2.28
# Actual= 1 - Predict= 2.29
# Actual= 1 - Predict= 2.27
# Actual= 1 - Predict= 2.27
# Actual= 3 - Predict= 2.27
# Actual= 1 - Predict= 2.28
# Actual= 2 - Predict= 2.27 =====CORRECT=====
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.28
#
# Lasso had an accuracy of 0.21904761904761905
#
# ===== ElasticNet =====
#
# Actual= 1 - Predict= 1.67
# Actual= 2 - Predict= 1.72 =====CORRECT=====
# Actual= 2 - Predict= 2.7
# Actual= 2 - Predict= 1.96 =====CORRECT=====
# Actual= 1 - Predict= 2.3
# Actual= 1 - Predict= 2.31
# Actual= 2 - Predict= 2.13 =====CORRECT=====
# Actual= 4 - Predict= 2.61
# Actual= 1 - Predict= 1.46 =====CORRECT=====
# Actual= 3 - Predict= 2.62 =====CORRECT=====
# Actual= 2 - Predict= 2.18 =====CORRECT=====
# Actual= 2 - Predict= 2.04 =====CORRECT=====
# Actual= 3 - Predict= 2.21
# Actual= 3 - Predict= 2.21
# Actual= 1 - Predict= 2.19
# Actual= 4 - Predict= 3.36
# Actual= 4 - Predict= 2.31
# Actual= 4 - Predict= 3.2
# Actual= 1 - Predict= 1.79
# Actual= 1 - Predict= 1.8
# Actual= 2 - Predict= 2.26 =====CORRECT=====
# Actual= 4 - Predict= 2.71
# Actual= 3 - Predict= 2.29
# Actual= 2 - Predict= 2.1 =====CORRECT=====
# Actual= 3 - Predict= 1.76
# Actual= 3 - Predict= 2.0
# Actual= 4 - Predict= 2.33
# Actual= 5 - Predict= 3.23
# Actual= 3 - Predict= 2.46
# Actual= 1 - Predict= 1.48 =====CORRECT=====
# Actual= 2 - Predict= 2.06 =====CORRECT=====
# Actual= 3 - Predict= 2.06
# Actual= 3 - Predict= 2.56 =====CORRECT=====
# Actual= 3 - Predict= 1.93
# Actual= 2 - Predict= 2.56
# Actual= 1 - Predict= 1.73
# Actual= 2 - Predict= 2.34 =====CORRECT=====
# Actual= 5 - Predict= 2.23
# Actual= 3 - Predict= 2.07
# Actual= 1 - Predict= 2.47
# Actual= 3 - Predict= 1.92
# Actual= 3 - Predict= 2.0
# Actual= 4 - Predict= 2.81
# Actual= 1 - Predict= 1.97
# Actual= 1 - Predict= 2.42
# Actual= 1 - Predict= 1.68
# Actual= 1 - Predict= 1.28 =====CORRECT=====
# Actual= 1 - Predict= 1.98
# Actual= 3 - Predict= 1.93
# Actual= 1 - Predict= 2.1
# Actual= 3 - Predict= 2.68 =====CORRECT=====
# Actual= 1 - Predict= 2.04
# Actual= 4 - Predict= 2.56
# Actual= 5 - Predict= 2.81
# Actual= 2 - Predict= 2.78
# Actual= 1 - Predict= 2.03
# Actual= 2 - Predict= 2.69
# Actual= 1 - Predict= 1.76
# Actual= 2 - Predict= 1.84 =====CORRECT=====
# Actual= 2 - Predict= 2.01 =====CORRECT=====
# Actual= 4 - Predict= 2.47
# Actual= 4 - Predict= 1.96
# Actual= 3 - Predict= 1.86
# Actual= 1 - Predict= 1.8
# Actual= 2 - Predict= 2.29 =====CORRECT=====
# Actual= 1 - Predict= 1.76
# Actual= 3 - Predict= 2.03
# Actual= 3 - Predict= 3.55
# Actual= 5 - Predict= 2.32
# Actual= 5 - Predict= 3.69
# Actual= 3 - Predict= 2.29
# Actual= 1 - Predict= 1.67
# Actual= 3 - Predict= 2.97 =====CORRECT=====
# Actual= 1 - Predict= 1.74
# Actual= 3 - Predict= 2.24
# Actual= 1 - Predict= 2.02
# Actual= 2 - Predict= 1.97 =====CORRECT=====
# Actual= 1 - Predict= 1.77
# Actual= 3 - Predict= 2.6 =====CORRECT=====
# Actual= 4 - Predict= 2.2
# Actual= 1 - Predict= 2.26
# Actual= 5 - Predict= 2.29
# Actual= 4 - Predict= 3.05
# Actual= 3 - Predict= 2.44
# Actual= 1 - Predict= 2.08
# Actual= 2 - Predict= 2.1 =====CORRECT=====
# Actual= 1 - Predict= 1.86
# Actual= 1 - Predict= 2.57
# Actual= 1 - Predict= 1.61
# Actual= 4 - Predict= 3.19
# Actual= 2 - Predict= 2.03 =====CORRECT=====
# Actual= 1 - Predict= 1.88
# Actual= 2 - Predict= 1.91 =====CORRECT=====
# Actual= 2 - Predict= 2.53
# Actual= 1 - Predict= 2.9
# Actual= 3 - Predict= 2.46
# Actual= 4 - Predict= 2.0
# Actual= 1 - Predict= 2.13
# Actual= 1 - Predict= 1.63
# Actual= 1 - Predict= 2.23
# Actual= 3 - Predict= 2.09
# Actual= 1 - Predict= 2.15
# Actual= 2 - Predict= 1.74 =====CORRECT=====
# Actual= 2 - Predict= 2.15 =====CORRECT=====
# Actual= 1 - Predict= 1.84
#
# ElasticNet had an accuracy of 0.24761904761904763

# %%
# Comparing results

for a, b, c in zip(default_results, param_results, best_features_results):
    print("Default parameters  -  " + str(a))
    print("Tuned parameters  -  " + str(b))
    print("Selected features  -  " + str(c))
    print()

# R2 scores
for p in preds:
    r2 = r2_score(y_test.values, p[0].predict(X_test))
    print("{} R2 score: {}".format(p[1], r2))
# Out:
# Default parameters  -  ['Linear Regression', 0.3142857142857143]
# Tuned parameters  -  ['Linear Regression', 0.3142857142857143]
# Selected features  -  ['Linear Regression', 0.3523809523809524]
#
# Default parameters  -  ['Ridge', 0.3142857142857143]
# Tuned parameters  -  ['Ridge', 0.3333333333333333]
# Selected features  -  ['Ridge', 0.3523809523809524]
#
# Default parameters  -  ['Lasso', 0.29523809523809524]
# Tuned parameters  -  ['Lasso', 0.29523809523809524]
# Selected features  -  ['Lasso', 0.21904761904761905]
#
# Default parameters  -  ['ElasticNet', 0.2761904761904762]
# Tuned parameters  -  ['ElasticNet', 0.2761904761904762]
# Selected features  -  ['ElasticNet', 0.24761904761904763]
#
# Linear Regression R2 score: 0.34039052813208215
# Ridge R2 score: 0.339671119320317
# Lasso R2 score: 0.00268589465407576
# ElasticNet R2 score: 0.2672914264725539

# %%
# Creating a confusion matrix

pred_models = [[lm, 'Linear Regression'], [ridge, 'Ridge'], [lasso, 'Lasso'], [ENet, 'ElasticNet']]

def plot_heatmap(model):
    predict = model[0].predict(X_test)
    
    cm = confusion_matrix(y_test.values, np.around(predict))

    df_cm = pd.DataFrame(cm, index = [i for i in class_names],
                      columns = [i for i in class_names])

    confmat = sns.heatmap(df_cm, annot=True)
    
    confmat.set_title('Confusion matrix of {} model'.format(model[1]))
    
    
plot_heatmap(pred_models[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in create_block_manager_from_blocks(blocks, axes)
#    1650                 blocks = [make_block(values=blocks[0],
# -> 1651                                      placement=slice(0, len(axes[0])))]
#    1652
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3094
# -> 3095     return klass(values, ndim=ndim, placement=placement)
#    3096
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in __init__(self, values, placement, ndim)
#      86                 'Wrong number of items passed {val}, placement implies '
# ---> 87                 '{mgr}'.format(val=len(self.values), mgr=len(self.mgr_locs)))
#      88
#
# ValueError: Wrong number of items passed 5, placement implies 6
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-24f108ad91df> in <module>
#      16
#      17
# ---> 18 plot_heatmap(pred_models[0])
#
# <ipython-input-10-24f108ad91df> in plot_heatmap(model)
#       9
#      10     df_cm = pd.DataFrame(cm, index = [i for i in class_names],
# ---> 11                       columns = [i for i in class_names])
#      12
#      13     confmat = sns.heatmap(df_cm, annot=True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     422             else:
#     423                 mgr = init_ndarray(data, index, columns, dtype=dtype,
# --> 424                                    copy=copy)
#     425
#     426         # For data is list-like, or Iterable (will consume into list)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_ndarray(values, index, columns, dtype, copy)
#     165         values = maybe_infer_to_datetimelike(values)
#     166
# --> 167     return create_block_manager_from_blocks([values], [columns, index])
#     168
#     169
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in create_block_manager_from_blocks(blocks, axes)
#    1658         blocks = [getattr(b, 'values', b) for b in blocks]
#    1659         tot_items = sum(b.shape[0] for b in blocks)
# -> 1660         construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    1661
#    1662
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in construction_error(tot_items, block_shape, axes, e)
#    1689         raise ValueError("Empty data passed with indices specified.")
#    1690     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 1691         passed, implied))
#    1692
#    1693
#
# ValueError: Shape of passed values is (5, 5), indices imply (6, 6)

# %%
plot_heatmap(pred_models[1])

# %%
plot_heatmap(pred_models[2])

# %%
plot_heatmap(pred_models[3])
