# %%
import sklearn
from sklearn.linear_model import ElasticNet, Lasso, Ridge, LogisticRegression, LinearRegression
import pandas as pd 
import numpy as np 
import matplotlib as plt
from sklearn.model_selection import train_test_split
from matplotlib import pyplot
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import plot_confusion_matrix
import seaborn as sns
from sklearn.metrics import confusion_matrix

# %%
# Loading data

data = pd.read_csv("Data/student-merge.csv")
data = pd.get_dummies(data, drop_first=True)
y = data["Walc"]
X = data.drop(["Dalc","Walc"],axis=1)
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=.1)

# %%
feature_names = [atts for atts in X]
class_names = ["1","2","3","4","5"]

# %%
lm = LinearRegression()
lm_fit = lm.fit(X_train, y_train)
lm_predict = lm_fit.predict(X_test)
lm_predict = np.around(lm_predict)

ridge = Ridge()
ridge_fit = ridge.fit(X_train,y_train)
r_predict = ridge_fit.predict(X_test)
r_predict = np.around(r_predict)

lasso = Lasso(max_iter=1000)
lasso_fit = lasso.fit(X_train,y_train)
l_predict = lasso_fit.predict(X_test)
l_predict = np.around(l_predict)

ENet = ElasticNet(l1_ratio=.01)
ENet_fit = ENet.fit(X_train,y_train)
en_predict = ENet_fit.predict(X_test)
en_predict = np.around(en_predict)

preds = [[lm_fit, 'Linear Regression'], [ridge_fit, 'Ridge'], [lasso_fit, 'Lasso'], [ENet_fit, 'ElasticNet']]

for p in preds:
    correct = 0
    print("====={}=====".format(p[1]))
    print()
    for i in range(len(X_test)):
        a = p[0].predict([X_test.iloc[i]])
        msg = ""
        if y_test.values[i] == np.around(a[0]):
            msg = "=====CORRECT====="
            correct += 1
        print("Actual= {} - Predict= {} {}".format(y_test.values[i],round(a[0],2), msg))
    print()
    print("{} had an accuracy of {}".format(p[1], correct/len(X_test)))
    print()
# Out:
# =====Linear Regression=====
#
# Actual= 1 - Predict= 1.94
# Actual= 4 - Predict= 3.19
# Actual= 2 - Predict= 1.97 =====CORRECT=====
# Actual= 2 - Predict= 3.11
# Actual= 2 - Predict= 1.13
# Actual= 5 - Predict= 3.04
# Actual= 2 - Predict= 2.78
# Actual= 4 - Predict= 4.42 =====CORRECT=====
# Actual= 2 - Predict= 2.88
# Actual= 3 - Predict= 3.23 =====CORRECT=====
# Actual= 1 - Predict= 1.09 =====CORRECT=====
# Actual= 1 - Predict= 1.77
# Actual= 3 - Predict= 2.94 =====CORRECT=====
# Actual= 1 - Predict= 1.6
# Actual= 3 - Predict= 2.37
# Actual= 2 - Predict= 1.86 =====CORRECT=====
# Actual= 1 - Predict= 2.02
# Actual= 2 - Predict= 2.84
# Actual= 3 - Predict= 1.9
# Actual= 3 - Predict= 1.87
# Actual= 2 - Predict= 1.92 =====CORRECT=====
# Actual= 1 - Predict= 2.16
# Actual= 1 - Predict= 2.19
# Actual= 2 - Predict= 1.98 =====CORRECT=====
# Actual= 1 - Predict= 2.35
# Actual= 4 - Predict= 1.95
# Actual= 2 - Predict= 3.36
# Actual= 2 - Predict= 1.91 =====CORRECT=====
# Actual= 1 - Predict= 2.22
# Actual= 4 - Predict= 2.84
# Actual= 3 - Predict= 3.55
# Actual= 2 - Predict= 1.74 =====CORRECT=====
# Actual= 2 - Predict= 2.48 =====CORRECT=====
# Actual= 1 - Predict= 1.41 =====CORRECT=====
# Actual= 1 - Predict= 1.38 =====CORRECT=====
# Actual= 4 - Predict= 3.23
# Actual= 3 - Predict= 1.91
# Actual= 1 - Predict= 1.99
# Actual= 2 - Predict= 1.06
# Actual= 3 - Predict= 1.51
# Actual= 3 - Predict= 3.34 =====CORRECT=====
# Actual= 1 - Predict= 1.92
# Actual= 2 - Predict= 3.3
# Actual= 4 - Predict= 2.3
# Actual= 3 - Predict= 2.24
# Actual= 3 - Predict= 3.71
# Actual= 3 - Predict= 0.65
# Actual= 2 - Predict= 1.56 =====CORRECT=====
# Actual= 3 - Predict= 2.12
# Actual= 1 - Predict= 3.07
# Actual= 3 - Predict= 3.42 =====CORRECT=====
# Actual= 1 - Predict= 1.84
# Actual= 2 - Predict= 3.33
# Actual= 4 - Predict= 2.99
# Actual= 1 - Predict= 2.17
# Actual= 1 - Predict= 2.81
# Actual= 1 - Predict= 1.5 =====CORRECT=====
# Actual= 1 - Predict= 2.18
# Actual= 1 - Predict= 1.34 =====CORRECT=====
# Actual= 3 - Predict= 3.68
# Actual= 2 - Predict= 0.97
# Actual= 1 - Predict= 2.69
# Actual= 3 - Predict= 1.45
# Actual= 3 - Predict= 2.23
# Actual= 3 - Predict= 2.59 =====CORRECT=====
# Actual= 4 - Predict= 2.66
# Actual= 3 - Predict= 3.49 =====CORRECT=====
# Actual= 1 - Predict= 1.74
# Actual= 1 - Predict= 1.81
# Actual= 1 - Predict= 2.11
# Actual= 2 - Predict= 1.62 =====CORRECT=====
# Actual= 3 - Predict= 1.45
# Actual= 1 - Predict= 1.87
# Actual= 1 - Predict= 1.78
# Actual= 1 - Predict= 1.8
# Actual= 4 - Predict= 3.0
# Actual= 2 - Predict= 2.3 =====CORRECT=====
# Actual= 4 - Predict= 3.37
# Actual= 5 - Predict= 3.24
# Actual= 1 - Predict= 2.29
# Actual= 2 - Predict= 2.11 =====CORRECT=====
# Actual= 4 - Predict= 2.16
# Actual= 2 - Predict= 4.17
# Actual= 3 - Predict= 2.7 =====CORRECT=====
# Actual= 1 - Predict= 1.98
# Actual= 4 - Predict= 2.68
# Actual= 1 - Predict= 2.04
# Actual= 3 - Predict= 2.66 =====CORRECT=====
# Actual= 1 - Predict= 1.91
# Actual= 1 - Predict= 1.51
# Actual= 2 - Predict= 1.31
# Actual= 1 - Predict= 2.66
# Actual= 1 - Predict= 1.34 =====CORRECT=====
# Actual= 3 - Predict= 3.58
# Actual= 2 - Predict= 2.11 =====CORRECT=====
# Actual= 1 - Predict= 1.1 =====CORRECT=====
# Actual= 1 - Predict= 1.94
# Actual= 3 - Predict= 2.08
# Actual= 1 - Predict= 2.52
# Actual= 4 - Predict= 3.24
# Actual= 1 - Predict= 2.04
# Actual= 2 - Predict= 2.4 =====CORRECT=====
# Actual= 3 - Predict= 2.55 =====CORRECT=====
# Actual= 4 - Predict= 1.76
# Actual= 1 - Predict= 2.09
#
# Linear Regression had an accuracy of 0.2857142857142857
#
# =====Ridge=====
#
# Actual= 1 - Predict= 1.95
# Actual= 4 - Predict= 3.18
# Actual= 2 - Predict= 1.98 =====CORRECT=====
# Actual= 2 - Predict= 3.11
# Actual= 2 - Predict= 1.15
# Actual= 5 - Predict= 3.04
# Actual= 2 - Predict= 2.78
# Actual= 4 - Predict= 4.41 =====CORRECT=====
# Actual= 2 - Predict= 2.88
# Actual= 3 - Predict= 3.23 =====CORRECT=====
# Actual= 1 - Predict= 1.09 =====CORRECT=====
# Actual= 1 - Predict= 1.77
# Actual= 3 - Predict= 2.93 =====CORRECT=====
# Actual= 1 - Predict= 1.6
# Actual= 3 - Predict= 2.37
# Actual= 2 - Predict= 1.86 =====CORRECT=====
# Actual= 1 - Predict= 2.02
# Actual= 2 - Predict= 2.83
# Actual= 3 - Predict= 1.9
# Actual= 3 - Predict= 1.88
# Actual= 2 - Predict= 1.92 =====CORRECT=====
# Actual= 1 - Predict= 2.16
# Actual= 1 - Predict= 2.19
# Actual= 2 - Predict= 1.99 =====CORRECT=====
# Actual= 1 - Predict= 2.34
# Actual= 4 - Predict= 1.95
# Actual= 2 - Predict= 3.36
# Actual= 2 - Predict= 1.91 =====CORRECT=====
# Actual= 1 - Predict= 2.21
# Actual= 4 - Predict= 2.83
# Actual= 3 - Predict= 3.54
# Actual= 2 - Predict= 1.74 =====CORRECT=====
# Actual= 2 - Predict= 2.48 =====CORRECT=====
# Actual= 1 - Predict= 1.42 =====CORRECT=====
# Actual= 1 - Predict= 1.38 =====CORRECT=====
# Actual= 4 - Predict= 3.23
# Actual= 3 - Predict= 1.92
# Actual= 1 - Predict= 1.99
# Actual= 2 - Predict= 1.05
# Actual= 3 - Predict= 1.52
# Actual= 3 - Predict= 3.34 =====CORRECT=====
# Actual= 1 - Predict= 1.92
# Actual= 2 - Predict= 3.3
# Actual= 4 - Predict= 2.3
# Actual= 3 - Predict= 2.25
# Actual= 3 - Predict= 3.7
# Actual= 3 - Predict= 0.66
# Actual= 2 - Predict= 1.56 =====CORRECT=====
# Actual= 3 - Predict= 2.11
# Actual= 1 - Predict= 3.07
# Actual= 3 - Predict= 3.42 =====CORRECT=====
# Actual= 1 - Predict= 1.84
# Actual= 2 - Predict= 3.32
# Actual= 4 - Predict= 2.99
# Actual= 1 - Predict= 2.17
# Actual= 1 - Predict= 2.81
# Actual= 1 - Predict= 1.5
# Actual= 1 - Predict= 2.18
# Actual= 1 - Predict= 1.34 =====CORRECT=====
# Actual= 3 - Predict= 3.67
# Actual= 2 - Predict= 0.97
# Actual= 1 - Predict= 2.69
# Actual= 3 - Predict= 1.45
# Actual= 3 - Predict= 2.24
# Actual= 3 - Predict= 2.59 =====CORRECT=====
# Actual= 4 - Predict= 2.66
# Actual= 3 - Predict= 3.48 =====CORRECT=====
# Actual= 1 - Predict= 1.74
# Actual= 1 - Predict= 1.81
# Actual= 1 - Predict= 2.1
# Actual= 2 - Predict= 1.62 =====CORRECT=====
# Actual= 3 - Predict= 1.45
# Actual= 1 - Predict= 1.86
# Actual= 1 - Predict= 1.79
# Actual= 1 - Predict= 1.8
# Actual= 4 - Predict= 3.0
# Actual= 2 - Predict= 2.29 =====CORRECT=====
# Actual= 4 - Predict= 3.37
# Actual= 5 - Predict= 3.24
# Actual= 1 - Predict= 2.29
# Actual= 2 - Predict= 2.11 =====CORRECT=====
# Actual= 4 - Predict= 2.16
# Actual= 2 - Predict= 4.16
# Actual= 3 - Predict= 2.69 =====CORRECT=====
# Actual= 1 - Predict= 1.97
# Actual= 4 - Predict= 2.68
# Actual= 1 - Predict= 2.04
# Actual= 3 - Predict= 2.66 =====CORRECT=====
# Actual= 1 - Predict= 1.91
# Actual= 1 - Predict= 1.52
# Actual= 2 - Predict= 1.32
# Actual= 1 - Predict= 2.65
# Actual= 1 - Predict= 1.34 =====CORRECT=====
# Actual= 3 - Predict= 3.57
# Actual= 2 - Predict= 2.12 =====CORRECT=====
# Actual= 1 - Predict= 1.11 =====CORRECT=====
# Actual= 1 - Predict= 1.93
# Actual= 3 - Predict= 2.09
# Actual= 1 - Predict= 2.52
# Actual= 4 - Predict= 3.23
# Actual= 1 - Predict= 2.04
# Actual= 2 - Predict= 2.4 =====CORRECT=====
# Actual= 3 - Predict= 2.55 =====CORRECT=====
# Actual= 4 - Predict= 1.76
# Actual= 1 - Predict= 2.09
#
# Ridge had an accuracy of 0.2761904761904762
#
# =====Lasso=====
#
# Actual= 1 - Predict= 2.29
# Actual= 4 - Predict= 2.31
# Actual= 2 - Predict= 2.32 =====CORRECT=====
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 2 - Predict= 2.31 =====CORRECT=====
# Actual= 5 - Predict= 2.3
# Actual= 2 - Predict= 2.31 =====CORRECT=====
# Actual= 4 - Predict= 2.35
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 3 - Predict= 2.28
# Actual= 1 - Predict= 2.29
# Actual= 1 - Predict= 2.28
# Actual= 3 - Predict= 2.3
# Actual= 1 - Predict= 2.28
# Actual= 3 - Predict= 2.28
# Actual= 2 - Predict= 2.29 =====CORRECT=====
# Actual= 1 - Predict= 2.31
# Actual= 2 - Predict= 2.29 =====CORRECT=====
# Actual= 3 - Predict= 2.28
# Actual= 3 - Predict= 2.28
# Actual= 2 - Predict= 2.3 =====CORRECT=====
# Actual= 1 - Predict= 2.28
# Actual= 1 - Predict= 2.29
# Actual= 2 - Predict= 2.29 =====CORRECT=====
# Actual= 1 - Predict= 2.31
# Actual= 4 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 2 - Predict= 2.3 =====CORRECT=====
# Actual= 1 - Predict= 2.29
# Actual= 4 - Predict= 2.32
# Actual= 3 - Predict= 2.29
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.29
# Actual= 1 - Predict= 2.29
# Actual= 4 - Predict= 2.29
# Actual= 3 - Predict= 2.29
# Actual= 1 - Predict= 2.31
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 3 - Predict= 2.28
# Actual= 3 - Predict= 2.3
# Actual= 1 - Predict= 2.29
# Actual= 2 - Predict= 2.29 =====CORRECT=====
# Actual= 4 - Predict= 2.29
# Actual= 3 - Predict= 2.3
# Actual= 3 - Predict= 2.29
# Actual= 3 - Predict= 2.29
# Actual= 2 - Predict= 2.29 =====CORRECT=====
# Actual= 3 - Predict= 2.28
# Actual= 1 - Predict= 2.29
# Actual= 3 - Predict= 2.29
# Actual= 1 - Predict= 2.28
# Actual= 2 - Predict= 2.31 =====CORRECT=====
# Actual= 4 - Predict= 2.31
# Actual= 1 - Predict= 2.3
# Actual= 1 - Predict= 2.3
# Actual= 1 - Predict= 2.29
# Actual= 1 - Predict= 2.29
# Actual= 1 - Predict= 2.28
# Actual= 3 - Predict= 2.32
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.28
# Actual= 3 - Predict= 2.28
# Actual= 3 - Predict= 2.29
# Actual= 3 - Predict= 2.28
# Actual= 4 - Predict= 2.28
# Actual= 3 - Predict= 2.31
# Actual= 1 - Predict= 2.31
# Actual= 1 - Predict= 2.3
# Actual= 1 - Predict= 2.29
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 3 - Predict= 2.28
# Actual= 1 - Predict= 2.31
# Actual= 1 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 4 - Predict= 2.28
# Actual= 2 - Predict= 2.29 =====CORRECT=====
# Actual= 4 - Predict= 2.35
# Actual= 5 - Predict= 2.31
# Actual= 1 - Predict= 2.29
# Actual= 2 - Predict= 2.31 =====CORRECT=====
# Actual= 4 - Predict= 2.31
# Actual= 2 - Predict= 2.29 =====CORRECT=====
# Actual= 3 - Predict= 2.31
# Actual= 1 - Predict= 2.29
# Actual= 4 - Predict= 2.29
# Actual= 1 - Predict= 2.3
# Actual= 3 - Predict= 2.29
# Actual= 1 - Predict= 2.29
# Actual= 1 - Predict= 2.28
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.31
# Actual= 1 - Predict= 2.28
# Actual= 3 - Predict= 2.28
# Actual= 2 - Predict= 2.3 =====CORRECT=====
# Actual= 1 - Predict= 2.31
# Actual= 1 - Predict= 2.3
# Actual= 3 - Predict= 2.28
# Actual= 1 - Predict= 2.28
# Actual= 4 - Predict= 2.3
# Actual= 1 - Predict= 2.3
# Actual= 2 - Predict= 2.32 =====CORRECT=====
# Actual= 3 - Predict= 2.29
# Actual= 4 - Predict= 2.29
# Actual= 1 - Predict= 2.28
#
# Lasso had an accuracy of 0.23809523809523808
#
# =====ElasticNet=====
#
# Actual= 1 - Predict= 2.33
# Actual= 4 - Predict= 2.83
# Actual= 2 - Predict= 2.5
# Actual= 2 - Predict= 2.4 =====CORRECT=====
# Actual= 2 - Predict= 2.27 =====CORRECT=====
# Actual= 5 - Predict= 2.93
# Actual= 2 - Predict= 2.62
# Actual= 4 - Predict= 3.27
# Actual= 2 - Predict= 2.55
# Actual= 3 - Predict= 2.58 =====CORRECT=====
# Actual= 1 - Predict= 1.82
# Actual= 1 - Predict= 1.97
# Actual= 3 - Predict= 2.36
# Actual= 1 - Predict= 1.91
# Actual= 3 - Predict= 2.24
# Actual= 2 - Predict= 2.22 =====CORRECT=====
# Actual= 1 - Predict= 2.26
# Actual= 2 - Predict= 2.29 =====CORRECT=====
# Actual= 3 - Predict= 2.06
# Actual= 3 - Predict= 1.9
# Actual= 2 - Predict= 2.1 =====CORRECT=====
# Actual= 1 - Predict= 2.25
# Actual= 1 - Predict= 2.5
# Actual= 2 - Predict= 2.32 =====CORRECT=====
# Actual= 1 - Predict= 2.13
# Actual= 4 - Predict= 2.11
# Actual= 2 - Predict= 2.79
# Actual= 2 - Predict= 2.46 =====CORRECT=====
# Actual= 1 - Predict= 2.08
# Actual= 4 - Predict= 2.55
# Actual= 3 - Predict= 2.43
# Actual= 2 - Predict= 1.9 =====CORRECT=====
# Actual= 2 - Predict= 2.18 =====CORRECT=====
# Actual= 1 - Predict= 2.0
# Actual= 1 - Predict= 1.77
# Actual= 4 - Predict= 2.78
# Actual= 3 - Predict= 2.29
# Actual= 1 - Predict= 1.98
# Actual= 2 - Predict= 1.46
# Actual= 3 - Predict= 1.93
# Actual= 3 - Predict= 2.65 =====CORRECT=====
# Actual= 1 - Predict= 2.29
# Actual= 2 - Predict= 2.43 =====CORRECT=====
# Actual= 4 - Predict= 2.36
# Actual= 3 - Predict= 2.66 =====CORRECT=====
# Actual= 3 - Predict= 2.82 =====CORRECT=====
# Actual= 3 - Predict= 1.62
# Actual= 2 - Predict= 2.02 =====CORRECT=====
# Actual= 3 - Predict= 2.17
# Actual= 1 - Predict= 2.4
# Actual= 3 - Predict= 2.47
# Actual= 1 - Predict= 1.98
# Actual= 2 - Predict= 2.51
# Actual= 4 - Predict= 2.74
# Actual= 1 - Predict= 2.38
# Actual= 1 - Predict= 2.5
# Actual= 1 - Predict= 1.56
# Actual= 1 - Predict= 2.02
# Actual= 1 - Predict= 2.0
# Actual= 3 - Predict= 2.71 =====CORRECT=====
# Actual= 2 - Predict= 1.89 =====CORRECT=====
# Actual= 1 - Predict= 2.28
# Actual= 3 - Predict= 1.74
# Actual= 3 - Predict= 2.43
# Actual= 3 - Predict= 2.31
# Actual= 4 - Predict= 2.55
# Actual= 3 - Predict= 2.94 =====CORRECT=====
# Actual= 1 - Predict= 2.08
# Actual= 1 - Predict= 1.97
# Actual= 1 - Predict= 2.06
# Actual= 2 - Predict= 1.94 =====CORRECT=====
# Actual= 3 - Predict= 1.89
# Actual= 1 - Predict= 2.1
# Actual= 1 - Predict= 1.99
# Actual= 1 - Predict= 2.01
# Actual= 4 - Predict= 2.79
# Actual= 2 - Predict= 1.88 =====CORRECT=====
# Actual= 4 - Predict= 3.14
# Actual= 5 - Predict= 3.0
# Actual= 1 - Predict= 2.37
# Actual= 2 - Predict= 2.11 =====CORRECT=====
# Actual= 4 - Predict= 2.52
# Actual= 2 - Predict= 3.11
# Actual= 3 - Predict= 2.48
# Actual= 1 - Predict= 2.06
# Actual= 4 - Predict= 2.52
# Actual= 1 - Predict= 2.14
# Actual= 3 - Predict= 2.49
# Actual= 1 - Predict= 1.87
# Actual= 1 - Predict= 1.87
# Actual= 2 - Predict= 1.69 =====CORRECT=====
# Actual= 1 - Predict= 2.42
# Actual= 1 - Predict= 1.74
# Actual= 3 - Predict= 2.82 =====CORRECT=====
# Actual= 2 - Predict= 2.28 =====CORRECT=====
# Actual= 1 - Predict= 2.12
# Actual= 1 - Predict= 1.99
# Actual= 3 - Predict= 2.32
# Actual= 1 - Predict= 2.14
# Actual= 4 - Predict= 2.76
# Actual= 1 - Predict= 1.98
# Actual= 2 - Predict= 2.39 =====CORRECT=====
# Actual= 3 - Predict= 2.12
# Actual= 4 - Predict= 2.21
# Actual= 1 - Predict= 1.96
#
# ElasticNet had an accuracy of 0.23809523809523808

# %%
# Linear Regression

grid_params = {
    'fit_intercept': ['True', 'False', 'optional']
}

gs_1 = GridSearchCV(LinearRegression(), grid_params)
gs_1 = gs_1.fit(X, y)
print("Best hyperparameter: fit_intercept: {}\n".format(gs_1.best_params_.get('fit_intercept')))

# Ridge

grid_params = {
    'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg']
}

gs_1 = GridSearchCV(Ridge(), grid_params)
gs_1 = gs_1.fit(X, y)
print("Best hyperparameter: solver: {}\n".format(gs_1.best_params_.get('solver')))

# Lasso

grid_params = {
    'normalize': [True, False, 'optional'] 
}

gs_1 = GridSearchCV(Lasso(), grid_params)
gs_1 = gs_1.fit(X, y)
print("Best hyperparameter: normalize: {}\n".format(gs_1.best_params_.get('normalize')))

# ElasticNet

grid_params = {
    'normalize': [True, False, 'optional'] 
}

gs_1 = GridSearchCV(ElasticNet(), grid_params)
gs_1 = gs_1.fit(X, y)
print("Best hyperparameter: normalize: {}\n".format(gs_1.best_params_.get('normalize')))
# Out:
# Best hyperparameter: fit_intercept: True
#
# Best hyperparameter: solver: lsqr
#
# Best hyperparameter: normalize: False
#
# Best hyperparameter: normalize: False

# %%
cm = confusion_matrix(y_test.values, lm_predict.astype(int))

df_cm = pd.DataFrame(cm, index = [i for i in class_names],
                  columns = [i for i in class_names])

sns.heatmap(df_cm, annot=True)
